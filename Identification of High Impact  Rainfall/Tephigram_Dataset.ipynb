# %%
import pandas as pd

data = [['PRES', 'HGHT', 'TEMP', 'DWPT', 'RELH', 'MIXR', 'DRCT', 'SKNT', 'THTA', 'THTE', 'THTV'],
        ['1009.0', '8', '29.6', '24.9', '76', '20.13', '240', '8', '302.0', '361.8', '305.6'],
        ['1000.0', '91', '27.6', '22.6', '74', '17.61', '250', '8', '300.8', '352.7', '303.9'],
        ['925.0', '777', '23.2', '18.2', '73', '14.43', '210', '6', '303.0', '346.0', '305.6'],
        ['850.0', '1512', '20.4', '16.0', '76', '13.64', '75', '8', '307.5', '348.9', '310.0'],
        ['700.0', '3163', '9.8', '4.9', '72', '7.82', '100', '23', '313.3', '337.9', '314.8'],
        ['500.0', '5880', '-3.7', '-24.7', '18', '1.04', '105', '16', '328.5', '332.3', '328.7'],
        ['400.0', '7610', '-15.7', '-24.7', '46', '1.30', '120', '19', '334.5', '339.3', '334.8'],
        ['300.0', '9710', '-32.1', '-40.1', '45', '0.39', '270', '14', '340.0', '341.6', '340.1'],
        ['250.0', '10980', '-41.1', '-51.1', '33', '0.14', '265', '27', '344.8', '345.4', '344.9'],
        ['200.0', '12450', '-53.9', '-61.9', '37', '0.05', '280', '31', '347.2', '347.5', '347.3'],
        ['150.0', '14240', '-68.1', '-75.1', '36', '0.01', '230', '33', '352.6', '352.6', '352.6'],
        ['100.0', '16570', '-82.3', '-88.3', '36', '0.00', '140', '23', '368.5', '368.5', '368.5']]

df = pd.DataFrame(data[1:], columns=data[0])
print(df)
# Out:
#       PRES   HGHT   TEMP   DWPT RELH   MIXR DRCT SKNT   THTA   THTE   THTV
# 0   1009.0      8   29.6   24.9   76  20.13  240    8  302.0  361.8  305.6
# 1   1000.0     91   27.6   22.6   74  17.61  250    8  300.8  352.7  303.9
# 2    925.0    777   23.2   18.2   73  14.43  210    6  303.0  346.0  305.6
# 3    850.0   1512   20.4   16.0   76  13.64   75    8  307.5  348.9  310.0
# 4    700.0   3163    9.8    4.9   72   7.82  100   23  313.3  337.9  314.8
# 5    500.0   5880   -3.7  -24.7   18   1.04  105   16  328.5  332.3  328.7
# 6    400.0   7610  -15.7  -24.7   46   1.30  120   19  334.5  339.3  334.8
# 7    300.0   9710  -32.1  -40.1   45   0.39  270   14  340.0  341.6  340.1
# 8    250.0  10980  -41.1  -51.1   33   0.14  265   27  344.8  345.4  344.9
# 9    200.0  12450  -53.9  -61.9   37   0.05  280   31  347.2  347.5  347.3
# 10   150.0  14240  -68.1  -75.1   36   0.01  230   33  352.6  352.6  352.6
# ...

# %%
#pip install siphon

#from siphon.soundings import Tephigram
#import matplotlib.pyplot as plt

from metpy.plots import SkewT, Hodograph
from siphon.simplewebservice.wyoming import WyomingUpperAir
import matplotlib.pyplot as plt

# Extract the data from the dataframe
p = df['PRES'].astype(float).values
z = df['HGHT'].astype(float).values
t = df['TEMP'].astype(float).values
td = df['DWPT'].astype(float).values

# Create a tephigram
#fig, ax = plt.subplots(figsize=(8, 8))
teph = SkewT()

# Plot the data on the tephigram
teph.plot(p, t, 'r')
teph.plot(p, td, 'g')
teph.plot_dry_adiabats()
teph.plot_moist_adiabats()
teph.plot_mixing_lines()

# Add axis labels and a title
teph.ax.set_xlabel('Temperature (C)')
teph.ax.set_ylabel('Pressure (hPa)')
teph.ax.set_title('Tephigram')

# Show the plot
plt.show()

# %%
# !pip install siphon

# %%
pip install siphon
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install metpy siphon
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from metpy.plots import SkewT, Hodograph
from siphon.simplewebservice.wyoming import WyomingUpperAir
import matplotlib.pyplot as plt
# Out:
# C:\Users\DANSO CHARITY JNR\anaconda3\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,
